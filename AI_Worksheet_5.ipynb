# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/Datasets/student.csv')

# %%
# Print top 5 rows
df.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
# Print bottom 5 rows
df.tail()
# Out:
#      Math  Reading  Writing
# 995    72       74       70
# 996    73       86       90
# 997    89       87       94
# 998    83       82       78
# 999    66       66       72

# %%
# Print dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     1000 non-null   int64
#  1   Reading  1000 non-null   int64
#  2   Writing  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB

# %%
# Print descriptive statistics
df.describe()
# Out:
#               Math      Reading      Writing
# count  1000.000000  1000.000000  1000.000000
# mean     67.290000    69.872000    68.616000
# std      15.085008    14.657027    15.241287
# min      13.000000    19.000000    14.000000
# 25%      58.000000    60.750000    58.000000
# 50%      68.000000    70.000000    69.500000
# 75%      78.000000    81.000000    79.000000
# max     100.000000   100.000000   100.000000

# %%
# Split data into features (X) and label (Y)
x = df[['Math', 'Reading']]
y = df['Writing']

# %%
import numpy as np

# %%
# Create matrices for linear regression
X_matrix = np.array(x)  # Feature matrix
Y_matrix = np.array(y).reshape(-1, 1)  # Label matrix reshaped as a column vector

# %%
# Display the shapes of the matrices
X_shape = X_matrix.shape
Y_shape = Y_matrix.shape

X_matrix[:5], Y_matrix[:5], X_shape, Y_shape
# Out:
# (array([[48, 68],
#         [62, 81],
#         [79, 80],
#         [76, 83],
#         [59, 64]]),
#  array([[63],
#         [72],
#         [78],
#         [79],
#         [62]]),
#  (1000, 2),
#  (1000, 1))
